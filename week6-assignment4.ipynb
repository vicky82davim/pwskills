# %%
"""
Q1. What is Flask Framework? What are the advantages of Flask Framework?
"""
"""
Flask framework is a python base framework used to develop web applications. 
Built-in development server and fast debugger
Restful request dispatching
Templating jinja2
Easy to connect with any database
"""

# %%
"""
Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
Jupyter Notebook.
"""

# %% [markdown]
# ![Hello-world.JPG](attachment:dc7c5c23-a1ed-4347-aef0-790a99cbe710.JPG)

# %%
"""
Q3. What is App routing in Flask? Why do we use app routes?
"""
"""
App Routing means mapping the URLs to a specific function that will handle the logic for that URL
"""

# %%
"""
Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
route to show the following details:
Company Name: ABC Corporation
Location: India
Contact Detail: 999-999-9999
Attach the screenshot of the output in Jupyter Notebook.
"""

# %% [markdown]
# ![welcome1.JPG](attachment:5639e55b-ee82-4744-82f0-cdd7c7ca4b8f.JPG)
# ![welcome2.JPG](attachment:53810f92-43f1-4601-9526-c51a204b6ca1.JPG)

# %%
"""
Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
url_for() function.
"""
"""
The url_for() function is used to build a URL to the specific function dynamically
"""
from flask import Flask, render_template, jsonify
from flask import request, url_for, redirect

app = Flask(__name__)

@app.route('/', methods = ['GET', 'POST'])
def home_page1():
    msg = """
    Company Name: ABC Corporation<br>
    Location: India<br>
    Contact Detail: 999-999-9999<br>
    """
    return msg

@app.route('/guest/<guest>')
def hello_guest(guest):
    return 'Hello %s as Guest' % guest


@app.route('/user/<name>')
def hello_user(name):
    print(name)
    if name =='welcome':
        return redirect(url_for('home_page1'))
    else:
        return redirect(url_for('hello_guest',guest = name))

if __name__=="__main__":
    app.run(host="0.0.0.0")
