# %%
"""
Q1. Explain GET and POST methods.
"""
"""
Get: Used to query sme data from DB. In Get, we send query parameter with URL. 
Post: Post method is used to insert, update DB. Parameters sent using Post method is not visible in URL
"""

# %%
"""
Q2. Why is request used in Flask?
"""
"""
Request methos contain the request object. With request object, we can check method (Get or Post). 
Get the form variables sent using form submit.
"""

# %%
"""
Q3. Why is redirect() used in Flask?
"""
"""
Redirect redirects users to a specified URL or API action and assign a specified status code
"""

# %%
"""
Q4. What are templates in Flask? Why is the render_template() function used?
"""
"""
render_template is used to generate output from a template file based on the HTML or Jinja2 engine 
that is found in the application's templates folder.
"""

# %%
"""
Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.
"""

# %% [markdown]
# ![postman.JPG](attachment:8e7041b5-77e6-401c-adbb-c5700d05894c.JPG)
